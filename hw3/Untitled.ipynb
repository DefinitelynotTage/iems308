# %% [markdown]
# # IEMS 308 HW3
# ## Author: Taige Hong

# %%
import os
import re
import nltk
import pandas as pd
import numpy as np

from nltk.corpus import stopwords, words
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from nltk.tokenize import RegexpTokenizer, sent_tokenize, word_tokenize
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Cleaning training data
#
# The raw data we have for the samples of each category is messy and needs to be cleaned. We want to put them into the same format so we can easily detect them in the article.

# %%
ceo_names = []
with open("all/ceo.csv", encoding = "ISO-8859-1") as f:
    ceo_names = f.readlines()

# %% [markdown]
# We put them in the form of Firstname Lastname, and remove the empty strings

# %%
def cleanceo(text):
    text = text.strip()
    text = text.rstrip()
    textlist = text.split(",")
    textlist = list(filter(None, textlist))
    
    if len(textlist) == 1:
        return textlist[0]
    else:
        return " ".join(textlist)

# %%
ceo_names = map(cleanceo, ceo_names)
ceo_names = list(set(ceo_names))

# %%
company_names = []
with open("all/companies.csv") as f:
    company_names = f.readlines()

# %% [markdown]
# We remove the extra space and period from the names

# %%
company_names = map(lambda x: x.rstrip(), company_names)
company_names = company_names.replace(".", "")
company_names = list(set(company_names))

# %% [markdown]
# We put all the text into a single string:

# %%
alltext = []

for file in os.listdir('2013/'):
    alltext.append(open(os.path.join('2013', file), 'rb').read().decode('ISO-8859-1'))
for file in os.listdir('2014/'):
    alltext.append(open(os.path.join('2014', file), 'rb').read().decode('ISO-8859-1'))

# %% [markdown]
# TrainTest splitting:

# %%
round(len(alltext)*0.7)
# Out:
# 511

# %%
traintext = alltext[0:round((len(alltext)*0.7))]
testtext = alltext[round((len(alltext)*0.7)):]

# %% [markdown]
# ## CEO
#
# First we want to find all the pairs with capital letter as the first:

# %%
conseCAP = []
for i in range(len(alltext)):
    conseCAP.append(re.findall(r'([A-Z]\w+) ([A-Z]\w+)',alltext[i]))
print(conseCAP[0])
# Out:
# [('And', 'Zerohedge'), ('Dragon', 'Boat'), ('But', 'Diana'), ('Lombard', 'Street'), ('Ting', 'Lu'), ('China', 'Banking'), ('Regulatory', 'Commission'), ('Charlene', 'Chu'), ('Lehman', 'China'), ('Das', 'Boot'), ('Michael', 'McDonough'), ('Twitter', 'Lu'), ('The', 'New'), ('York', 'Times'), ('Adam', 'Bryant'), ('Senior', 'Vice'), ('People', 'Operations'), ('Laszlo', 'Bock'), ('Chinese', 'Flash'), ('FinViz', 'This'), ('ReutersHSBC', 'China'), ('Flash', 'PMI'), ('The', 'HSBC'), ('China', 'Flash'), ('Manufacturing', 'PMI'), ('Hongbin', 'Qu'), ('Markit', 'Economics'), ('Markit', 'Economics'), ('HSBC', 'China'), ('The', 'National'), ('Statistics', 'PMI'), ('The', 'Nikkei'), ('The', 'FOMC'), ('Ben', 'Bernanke'), ('The', 'Nikkei'), ('Yahoo', 'Finance'), ('Jonanthan', 'ErnstYields'), ('Federal', 'Reserve'), ('Federal', 'Reserve'), ('Chairman', 'Ben'), ('Maury', 'Harris'), ('Bloomberg', 'TelevisionBloomberg'), ('Trish', 'Regan'), ('Bill', 'GrossPIMCO'), ('Bill', 'Gross'), ('Bloomberg', 'Television'), ('Trish', 'Regan'), ('Adam', 'Johnson'), ('Bloomberg', 'Television'), ('On', 'Janet'), ('Main', 'Street'), ('Wall', 'Street'), ('At', 'PIMCO'), ('Fred', 'ProuserMohamed'), ('Erian', 'Virtually'), ('Chairman', 'Ben'), ('Chairman', 'Bernanke'), ('APRio', 'De'), ('Sao', 'Paolo'), ('In', 'SÃ'), ('Eydar', 'Peralta'), ('FA', 'Insights'), ('Business', 'Insider'), ('Vadim', 'Zlotnikov'), ('Gives', 'Us'), ('The', 'Argument'), ('For', 'Active'), ('Business', 'Insider'), ('Jack', 'Bogle'), ('Vadim', 'Zlotnikov'), ('Date', 'Funds'), ('Growth', 'In'), ('Assets', 'Last'), ('Goldman', 'Sachs'), ('Oppenheimer', 'Funds'), ('The', 'Chart'), ('That', 'Predicts'), ('Without', 'Fail'), ('Gluskin', 'Sheff'), ('Gluskin', 'Sheff'), ('David', 'Rosenberg'), ('Gluskin', 'Sheff'), ('FINRA', 'Requests'), ('Information', 'On'), ('How', 'Brokerages'), ('And', 'Their'), ('Top', 'Representatives'), ('Are', 'Using'), ('Social', 'Media'), ('Financial', 'Industry'), ('Regulatory', 'Authority'), ('FINRA', 'Rule'), ('The', 'Only'), ('Place', 'Investors'), ('Will', 'Make'), ('Money', 'In'), ('The', 'Coming'), ('Weeks', 'Is'), ('The', 'Most'), ('Hated', 'Asset'), ('Class', 'On'), ('The', 'Planet'), ('Wall', 'Street'), ('Jeff', 'Gundlach'), ('Wall', 'Street'), ('Jon', 'Hilsenrath'), ('Santelli', 'Exchange'), ('Weimar', 'RepublicÂ'), ('Federal', 'Reserve'), ('Fed', 'Chairman'), ('Ben', 'Bernanke'), ('PM', 'ET'), ('The', 'FOMC'), ('Federal', 'Reserve'), ('Jason', 'ReedU'), ('Federal', 'Reserve'), ('Chairman', 'Ben'), ('Federal', 'Reserve'), ('Federal', 'Reserve'), ('Chairman', 'Ben'), ('The', 'FOMC'), ('Kit', 'Juckes'), ('Federal', 'Reserve'), ('Frank', 'PolichIt'), ('Ben', 'Bernanke'), ('The', 'Federal'), ('Fed', 'Chairman'), ('Ben', 'Bernanke'), ('PM', 'ET'), ('The', 'Fed'), ('Eli', 'Chess'), ('Chess', 'But'), ('Alana', 'Kakoyiannis'), ('Follow', 'BI'), ('On', 'Facebook'), ('At', 'Bernanke'), ('YouTubeFired', 'Men'), ('George', 'Zimmer'), ('The', 'Board'), ('George', 'Zimmer'), ('Executive', 'Chairman'), ('The', 'Board'), ('Annual', 'Meeting'), ('The', 'Company'), ('Annual', 'Meeting'), ('The', 'Company'), ('Annual', 'Meeting'), ('Exchange', 'Commission'), ('Annual', 'Meeting'), ('Frank', 'PolichThe'), ('Federal', 'Reserve'), ('June', 'FOMC'), ('Fed', 'Chairman'), ('Ben', 'Bernanke'), ('The', 'Fed'), ('The', 'Fed'), ('Release', 'Date'), ('Federal', 'Open'), ('Market', 'Committee'), ('The', 'Committee'), ('The', 'Committee'), ('The', 'Committee'), ('The', 'Committee'), ('The', 'Committee'), ('The', 'Committee'), ('The', 'Committee'), ('Vice', 'Chairman'), ('Sarah', 'Bloom'), ('James', 'Bullard'), ('Joint', 'Economic'), ('Labor', 'Day'), ('The', 'Federal'), ('Federal', 'Reserve'), ('Federal', 'Reserve'), ('Federal', 'Reserve'), ('Federal', 'Reserve'), ('Federal', 'Reserve'), ('New', 'York'), ('Emaar', 'Properties'), ('Mohammed', 'Alabbar'), ('Kingdom', 'Holding'), ('New', 'York'), ('Middle', 'EastÂ'), ('Burj', 'Khalifa'), ('Kingdom', 'TowerÂ'), ('Kingdom', 'Holding'), ('Saudi', 'Ara ...

# %% [markdown]
# We need to expand the stop word set for the CEO names as some of the words are unlikely to be names. The words we should focus on are those capped but not names.

# %%
stop_words=sorted(set(stopwords.words("english")))
stopwordceo = ["facebook", "twitter", "yahoo", "instagram", "apple", "samsung", "google", "amazon", "fed", "federal", "government", "republican", "republic", "democratic", "democrat", "president", "national", "social", "paper", "chair", "finance", "chief", "officer", "tax", "business", "financial", "capital", "company", "citi", "jp", "jpmorgan", "index", "corp", "inc", "co", "corporation", "ltd", "bank" "group", "ceo", "nasdaq", "world", "usa","us", "european", "europe", "japan", "china", "chinese", "america", "american", "ny", "nyc", "state", "city", "beijing", "shanghai", "eu", "london", "paris", "asia", "asian", "mexico", "mexican", "russia", "england", "arab", "university", "college", "school", "professor", "prof", "police", "news", "bank", "airline", "south", "north", "east","one", "first", "two", "second", "II", "three", "third", "III", "alpha", "beta", "theta", "kappa", "gamma", "mr", "nba", "cbs", "news", "fbi", "times", "today"] + stop_words
stopwordceo2 = ["hong kong", "white house", "new york", "san francisco", "wall street", "los angeles", "warner bros", "goldman sachs"]
conseCAP = []
for i in range(len(traintext)):
    pairs = re.findall(r'([A-Z]\w+) ([A-Z]\w+)',traintext[i])
    pairs = [t for t in pairs if ((t[0].lower() not in stopwordceo) & (t[1].lower() not in stopwordceo) & ((t[0] + " " + t[1]).lower() not in stopwordceo2))]
    for k in range(len(pairs)):
        conseCAP.append(pairs[k])
conseCAP = list(conseCAP)

# %%
insample = [t for t in conseCAP if (t[0] + ' ' + t[1]) in ceo_names]
len(insample)
# Out:
# 7719

# %% [markdown]
# The postive and negative samples are so imbalanced so we have to ensure that negative sample list has the same length as the positive sample list. Then we removed the duplicate names in 'insample'.

# %%
negsample = [t for t in conseCAP if (t[0] + ' ' + t[1]) not in ceo_names]
insampleid = list(set(insample))
len(insampleid)
# Out:
# 646

# %%
tokenizer = RegexpTokenizer("[A-Za-z]+'?[A-Za-z0-9]?")

# %% [markdown]
# The list of features I used includes:
#
# * If __ceo__ is in the sentence
# * If __chief, executive, officer__ is in the sentence respectively
# * If there are numbers in the sentence
# * The length of the sentence(number of words)
# * Length of the first name
# * Length of the last name
# * Proportion of capital letter
# * If the previous word has capital letter in the beginning
# * If the next word has capital letter in the beginning

# %%
def featureceo(sent, CAPS):
#We want to generate a list of features for a word showing up in a sentence. Ideally the features do not describe the
#pair of stop words itself in too much detail, as it will not provide useful information about future prediction. 
#Before running this function we have to make sure CAPS is in sent.
    word = tokenizer.tokenize(sent)
    lwords = map(lambda x : x.lower(), word)
    features = {"words": CAPS}
    features["insample"] = (CAPS in insample) + 0
    features["ceo_in_sent"] = ("ceo" in lwords) + 0
    features["chief_in_sent"] = ("chief" in lwords) + 0
    features["exec_in_sent"] = ("executive" in lwords) + 0
    features["officer_in_sent"] = ("officer" in lwords) + 0
    
    features["num_in_sent"] = (re.search(r'[0-9]+', sent) != None) + 0
    features["length_of_sent"] = len(word)
    features["length_of_first"] = len(CAPS[0])
    features["length_of_last"] = len(CAPS[1])
    
    wordlist = "".join(CAPS)
    features["portion_of_CAP"] = sum(map(lambda x: x.isupper(), wordlist))/len(wordlist)
    
    index = word.index(CAPS[0])
    features["prev_capped"] = ((index != 0) & (word[index-1][0].isupper())) + 0
    features["next_capped"] = ((index != len(word) - 2) & (word[-len(word) + index + 2][0].isupper())) + 0
    
    return features

# %%
trainsent = " ".join(traintext)
trainsent = sent_tokenize(trainsent)

# %% [markdown]
# Here we make sure the length of positive list is about the same as the negative list

# %%
poscount = 0
negcount = 0
featuremat = []
for i in range(len(trainsent)):
    twoCAPS = re.findall(r" ([A-Z][A-Za-z0-9']+) ([A-Z][A-Za-z0-9']+)", trainsent[i])
    for j in range(len(twoCAPS)):
        if (twoCAPS[j] in insample):
            poscount = poscount + 1
            featuremat.append(featureceo(trainsent[i], twoCAPS[j]))

for i in range(len(trainsent)):
    twoCAPS = re.findall(r" ([A-Z][A-Za-z0-9']+) ([A-Z][A-Za-z0-9']+)", trainsent[i])
    if (negcount >= len(insample)):
        break
    else:
        for j in range(len(twoCAPS)):
            if (twoCAPS[j] in negsample):
                negcount = negcount + 1
                featuremat.append(featureceo(trainsent[i], twoCAPS[j]))

# %%
featuremat = pd.DataFrame(featuremat)

# %% [markdown]
# We use the logistic regression to predict the label

# %%
y_train = featuremat["insample"]
X_train = featuremat.drop(["insample", "words"], axis = 1)
X_train = np.array(X_train)
clf = LogisticRegression().fit(X_train, y_train)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
conseCAP = []
for i in range(len(testtext)):
    pairs = re.findall(r'([A-Z]\w+) ([A-Z]\w+)',testtext[i])
    pairs = [t for t in pairs if ((t[0].lower() not in stopwordceo) & (t[1].lower() not in stopwordceo) & ((t[0] + " " + t[1]).lower() not in stopwordceo2))]
    for k in range(len(pairs)):
        conseCAP.append(pairs[k])
conseCAP = list(set(conseCAP))

# %%
testsent = " ".join(testtext)
testsent = sent_tokenize(testsent)

# %% [markdown]
# We construct the test matrix. To reduce runtime, we perform checkings before actually dumping the pair of word to the function.

# %%
testmat = []
def notcontainstopceo(pairs):
    return (any(map(lambda x: x not in stopwordceo, pairs)) & (pairs not in stopwordceo2))

for i in range(len(testsent)):
    twoCAPS = re.findall(r" ([A-Z][A-Za-z0-9']+) ([A-Z][A-Za-z0-9']+)", testsent[i])
    twoCAPS = list(filter(notcontainstopceo, twoCAPS))
    for j in range(len(twoCAPS)):
        if (twoCAPS[j] in conseCAP):
            testmat.append(featureceo(testsent[i], twoCAPS[j]))

# %% [markdown]
# Given the fact that the negative samples are about the same as positive ones in the training set, the result here is satisfactory.

# %%
testmat = pd.DataFrame(testmat)
X_test = testmat.drop(["insample", "words"], axis = 1)
y_test = testmat["insample"]
clf.score(X_test, y_test)
# Out:
# 0.8086323299625578

# %%
confusion_matrix(clf.predict(X_test), np.array(y_test))
# Out:
# array([[53653,  1490],
#        [11492,  1203]])

# %% [markdown]
# We apply the algorithm to the entire data set to detect for CEO names.

# %%
def predict_ceo(model, sent, CAPS):
    features = featureceo(sent, CAPS)
    features = pd.DataFrame(features)
    X = features.drop(["insample", "words"], axis = 1)
    X = X.drop(0)
    y = model.predict(X)
    return y[0]

# %%
allsent = " ".join(alltext)
allsent = sent_tokenize(allsent)

# %%
conseCAP = []
for i in range(len(alltext)):
    pairs = re.findall(r'([A-Z]\w+) ([A-Z]\w+)',alltext[i])
    pairs = [t for t in pairs if ((t[0].lower() not in stopwordceo) & (t[1].lower() not in stopwordceo) & ((t[0] + " " + t[1]).lower() not in stopwordceo2))]
    for k in range(len(pairs)):
        conseCAP.append(pairs[k])
conseCAP = list(set(conseCAP))

# %%
allceo = []
def notcontainstopceo(pairs):
    return (any(map(lambda x: x not in stopwordceo, pairs)) & (pairs not in stopwordceo2))

for i in range(len(allsent)):
    twoCAPS = re.findall(r" ([A-Z][A-Za-z0-9']+) ([A-Z][A-Za-z0-9']+)", allsent[i])
    twoCAPS = list(filter(notcontainstopceo, twoCAPS))
    for j in range(len(twoCAPS)):
        if (twoCAPS[j] in conseCAP):
            if (predict_ceo(clf, allsent[i], twoCAPS[j]) == 1):
                allceo.append(twoCAPS[j])

# %% [markdown]
# We write the results into the *predicted_ceo.txt* file

# %%
allceo = list(set(allceo))
with open("predicted_ceo.txt", "w") as f:
    for ceos in allceo:
        f.write(" ".join(ceos) + "\n")

# %% [markdown]
# We can see that the most helpful features are:
# * Whether or not **ceo** is in sentence
# * Whether or not **executive** is in sentence
# * Whether or not **officer** is in sentence
#
# It is interesting to see that the last two features are negatively correlated with the result. It might be that in articles we don't usually see the full title as "chief executive officer". Instead, they are using "ceo" as it is the more professional term in articles.

# %%
clf.coef_
# Out:
# array([[ 2.56296836,  0.36121931, -0.84846931, -0.21069949, -0.11119558,
#         -0.00449125, -0.75450733, -0.19632693, -0.97918579, -0.03946271]])

# %%
featuremat.head(1)
# Out:
#    ceo_in_sent  chief_in_sent  exec_in_sent  insample  length_of_first  \
# 0            0              0             0         1                4
#
#    length_of_last  length_of_sent  next_capped  num_in_sent  officer_in_sent  \
# 0               5              31            1            0                0
#
#    prev_capped          words
# 0            0  (Bill, Gross)

# %% [markdown]
# ## Company

# %% [markdown]
# The first task is to identify the common feature of the company names. We can see the majority of the names start with capital letters. There are only 7 counter-examples. Among them, only 'iSectors LLC' and 'eBay' have lowercase letters at the first position because it is intended, while 'interim', 'twenty-something' and 'the Human Rights Foundation' should be capitalized but was not. '2100 Xenon' and '20th Century Fox' start with numbers. Because the portion is so small within the entire list, we decide not to consider these counter-examples as they demand complicated investigation which could bring more false positives than simply not considering them and have some false negatives.

# %%
list(filter(lambda x: (not x[0].istitle()), company_names))
# Out:
# ['interim',
#  'iSectors LLC',
#  '2100 Xenon',
#  'eBay',
#  'the Human Rights Foundation',
#  'twenty-something',
#  '20th Century Fox']

# %%
company_names
# Out:
# ['Charles Schwab',
#  'AOL',
#  'Netflix Inc',
#  'Wisconsin',
#  'Delta',
#  'Best Paid Banking',
#  'Dion Weisler',
#  'Pandora Media',
#  'Scott Olson Twitter',
#  'Dell Inc',
#  'Portuguese Bank Espirito Santo',
#  'Deloitte',
#  'Birch Gold Group',
#  'W Corporation',
#  'Templeton Investments',
#  'Loan Pricing Corp',
#  'Shack Corp',
#  'Abaxis Inc',
#  'Current',
#  'Athlon Energy Inc',
#  'Telecom Italia',
#  'Investments Inc',
#  'Metlife',
#  'Fiat Chrysler',
#  'Spacex',
#  'Whole Foods',
#  'Bombardiar',
#  'Peugeot',
#  'Alireza Group',
#  'Chatillon',
#  'CNBC',
#  'Crain Communications',
#  'EMC Corp',
#  'Missiles Corporation',
#  'City Corp',
#  'Greenlight Capital',
#  'China Huarong Asset Management Co Ltd',
#  'US Bancorp',
#  'Ally Financial Inc',
#  'D.R. Horton',
#  'United Continental Holdings Inc',
#  'Goldman Sachs',
#  'Corelogic',
#  'Taxi Club Management',
#  'Samsung',
#  'Chipotle Mexican Grill Inc',
#  'Affiliated Managers Group',
#  'Fendi',
#  'Snapfish',
#  'Virgin Group',
#  'Civil Supplies Corporation',
#  'Lorillard Inc',
#  'NASDAQ',
#  'Lehman Brothers',
#  'Anglo Irish Bank',
#  'The Colony Group',
#  'Micro Financial Services Group',
#  'Highbridge Capital',
#  'Marine Insurance Co Ltd',
#  'China Pacific Insurance Group',
#  'Universal Basic Inc',
#  'Climate Corp',
#  'Lockheed Martin Corp',
#  'Icebreakers Group',
#  'U.S. Silica Holdings',
#  'Carver Bancorp.',
#  'The Howard Hughes Corporation',
#  'Westor Capital Group Inc',
#  'Starbucks Coffee Company',
#  'Statoil',
#  'Airways Corporation',
#  'Deseret Management Corporation',
#  'PdVSA',
#  'Cliffs Natural',
#  'Vermin Inc',
#  'Fairholme Capital Management',
#  'BlackRock',
#  'Virgin America',
#  'Mortgage Corporation',
#  'Chipotle',
#  'Jumptap',
#  'Rongzhong Group',
#  'Sony Corp',
#  'Zhongjiang Group',
#  'Bethlehem Steel Corporation',
#  'WhatsApp',
#  'Apple Inc',
#  'Zhejiang Jiayuan Group',
#  'Nucor Corp',
#  'Xiaomi',
#  'Qualcomm',
#  'Herbalife Inc',
#  'Barrel Old Country Store Inc',
#  'First Defense Nasal Screens',
#  'Gallup',
#  'General Electric',
#  'Actavis',
#  'China National Petroleum Corporation',
#  'COFCO Corp',
#  'The Tokmakjian Group',
#  'Recruit Holdings',
#  'Professional Coin Grading Service',
#  'Olorama',
#  'Equity Inc',
#  'Venoco Inc',
#  'Google',
#  'Hess Corp',
#  'Gleacher',
#  'Ventures Energy Corporation',
#  'Selling Strategy To Lower Inc',
#  'Tesla Motors',
#  'Equity Group',
#  'Altimeter Group',
#  'ChatPerf',
#  'Diamonds',
#  'Mastercard',
#  'Electrical Equipment Manufacturing Co Ltd',
#  'Pizza Inc',
#  'CSR Corp',
#  'Lockheed Martin Corporation',
#  'Time Inc',
#  'Mitsubishi Chemical Corporation',
#  'Southern Corporation',
#  'Energy Corp',
#  'Pepperstone',
#  'Protalix',
#  'Galleon Group',
#  'Sears Canada',
#  'National Petroleum Corporation',
#  'Catterpillar Inc',
#  'Integrys Energy Group Inc',
#  'Ferrero',
#  'Disk Corp',
#  'Omnicare Inc',
#  'SAC',
#  'Beijing Xinwei Telecom Technology Inc',
#  'Hertz Equipment Rental Corporation',
#  'Avista Capital Partners',
#  'Illumina Inc',
#  'Caesars Entertainment',
#  'Templeton Emergin Markets Group',
#  'Internet Corporation',
#  'Kajima Corp',
#  'Intel',
#  'Herbalife',
#  'Corp Capital',
#  'Zero Gravity Corporation',
#  'Airways Group Inc',
#  'Smartcredit.com',
#  'Total Inc',
#  'Rock Inc',
#  'NASA',
#  'Kroger Co',
#  'Investor Protection Corporation',
#  'Github',
#  'Financial Corp',
#  'Royal Bank of Scotland',
#  'Aetna',
#  'Walk Score',
#  'Williams Power Co',
#  'Red Robin Gourmet Burgers',
#  'IBERIABANK Corp',
#  'Hughes Corporation',
#  'Haima Automobile Group',
#  'Mitsubishi Motors Corp',
#  'Oceanographic',
#  'Tianbao',
#  'Hamilton Place Strategies',
#  "Macy's",
#  'Intuit',
#  'Oriental Brewery Co Ltd',
#  'American Chrysler Corporation',
#  'Hilton',
#  'Patriot National Bank',
#  'Fixed Inc',
#  'Spirit Airlines Inc',
#  'Pictures Corporation',
#  'Virgin',
#  'South African Broadcasting Corporation',
#  'Nissan Motor Co',
#  'General Motors Acceptance Corp',
#  'NYSE',
#  'KPMG',
#  'Caterpillar Inc',
#  'Daiichi Sankyo Co Ltd',
#  'Free Trade Zone Development Co Ltd',
#  'Starr International',
#  'Space',
#  'Archer Limited',
#  'Mazda Motor Corp',
#  'Strait Wealth Management Group',
#  'Dell Computer',
#  'Alcoa Inc',
#  'Yahoo',
#  'Columbia Pictures Corp',
#  'World Bank Group',
#  'Tokmakjian Group',
#  'KDDO Corporation',
#  'Dolce',
#  'Ryanair',
#  'Medivation Inc',
#  'New Zealand Army Corp',
#  'Marin Software',
#  'China National Nuclear Corp',
#  'Newmont Mining Corp',
#  'Three Gorges Corp',
#  'Pando',
#  'Soros Fund Management',
#  'Kyte Group',
#  'Irish Bank Resolution Corp',
#  'The Ensemble Practice',
#  'Dodge',
#  'Delhaize Group',
#  'Habib Medical Group',
#  'Banking Corporation',
#  'Entertainment Inc',
#  'Equipment Corporation',
#  'SurveyMonkey',
#  'Autonomy',
#  'Pine River Capital',
#  'Quonset Development Corporation',
#  'Individual Inc',
#  'Reis Inc',
#  'Stream Yahoo',
#  'Twitter Inc',
#  'Streettalk Advisors',
#  'Gannett Co Inc',
#  'Pharmacia Corp',
#  'Manpower Group',
#  'Cheniere Energy',
#  'General Motors Corporation',
#  'Bridgewater Associates',
#  'Serv Corp',
#  'Facebook',
#  'Exxon Mobil',
#  'Schork Group Inc',
#  'Lehman',
#  'Nortel Network Corp',
#  'Canon',
#  'Pemex',
#  'Dollar Thrifty Automotive Group',
#  'Forbes',
#  'Roche',
#  'TMobile',
#  'Oculus VR',
#  'N Broadcasting Corporation',
#  'Honda Motor Corp',
#  'Effective Inc',
#  'National Corporation',
#  'Michael Jackson Inc',
#  'Abel Advisors',
#  'Stewart Enterprises Inc',
#  'Humavox',
#  'Crown Corporation',
#  'Tremor Video',
#  'Guarantee Corporation',
#  'Canadian Corsa Coal Corp',
#  'Marathon Petroleum Corp',
#  'Metacapital Partners',
#  'SAIC Motor Corp',
#  'Travelers Group',
#  'Point Inc',
#  'Comfort Corporation',
#  'Lyft',
#  'Alstom',
#  'Elliot Management Corporation',
#  'Michaels Stores Inc',
#  'SigmaX',
#  'Countrywide',
#  'Consolidated Edison Inc',
#  'Cummins Inc',
#  'Zhongrong Metal Products Co Ltd',
#  'Lehman Brothers Inc',
#  'The Icahn Group',
#  'Raymond James Financial Inc',
#  'Sierra Nevada Corp',
#  'JPMorgan',
#  'Skin Enterprises Inc',
#  'Mubadala Development Corp',
#  'Sands Corporation',
#  'California Housing Partnership Corp',
#  'United Airlines Continental Holdings Inc',
#  'Quiznos',
#  'Personal Inc',
#  'GMars Corp',
#  'Elliott Management Corp',
#  'Kellogg',
#  'New York Mellon Corporation',
#  'BitPay',
#  'Citizens Financial Group Inc',
#  'The Andriole Group',
#  'Insurer American International Group',
#  'Qingquan Steel Group',
#  'interim',
#  'Fujitsu Ltd',
#  'Pixar',
#  'Natural Gas Corporation',
#  'Iowa Lottery',
#  'Rail Construction Corporation',
#  'Alcoa',
#  'FireEye',
#  'Salesforce',
#  'Nexen Inc',
#  'Charoen Pokphand Group',
#  'Smithfield Foods Inc',
#  'Protection Corporation',
#  'Coral Springs',
#  'Two',
#  'Construction Corporation',
#  'America Inc',
#  'Investment Strategy Group',
#  'Norwegian Cruise Line',
#  'Fossil',
#  'Cleary Gottlieb Steen',
#  'Shack Corporation',
#  'China National Offshore Oil Corp',
#  'F Corporation',
#  'Canalys',
#  'Reserve Management Co',
#  'Nordstrom Inc',
#  'Mogul Corporation',
#  'Vanguard Group',
#  'AEGIS FinServ Corp.',
#  'Bay Communities Inc',
#  'Communications Holdings Inc',
#  'Thomson Reuters Corp',
#  'Fossil Group',
#  'Real Vision Television',
#  'MGM',
#  'Daddy Group',
#  'Mapp Biopharmaceutical Inc',
#  'Pinnacle Advisory Group',
#  'Skype',
#  'Hasbro',
#  'Time Warner Cable',
#  'Nokia',
#  'Zhejiang Geely Holding Group',
#  'Fisher Communications Inc',
#  'X Corporation',
#  'Backed Securities Working Group',
#  'Galaxy Entertainment Group',
#  'Ethiopia',
#  'Upside',
#  'Investment Grade Corp',
#  'Monday Allergan Inc',
#  'BNY Mellon Corp',
#  'Bitcoin Group',
#  'Realty Guild Inc',
#  'Federal Deposit Insurance Corporation',
#  'Energy Inc',
#  'Federal Reality Investment Trust',
#  'Beyond Inc',
#  'Renewable Heat Inc',
#  'Capital Economics',
#  'Montaigne Inc',
#  'Office Depot Inc',
#  'Sino Forest Corp',
#  'The Vision Group',
#  'General Motors Co.',
#  'Sony Entertainment',
#  'Realty Income Corp',
#  'Solar Holdings Co Ltd',
#  'Baupost Group',
#  'Alice Corp',
#  'Bank of China',
#  'Devon Energy Corporation',
#  'Digital Media Group',
#  'Valeant Pharmaceuticals International Inc',
#  'Starbucks Co',
#  'Steve Blumenthal',
#  'Chesapeake Energy',
#  'Hong Kong Monetary Authority',
#  'Wealth Logic',
#  'Gulfstream Aerospace Corp',
#  'FINRA',
#  'Alaska Air Group',
#  'BBVA',
#  'Globalfoundries Inc',
#  'Bear Stearns',
#  'International Corporation',
#  'Samsung Heavy Industries Co Ltd',
#  'Mitsubishi Corp',
#  'International Business Machines Corp',
#  'T Corporation',
#  'USA Today',
#  'Natural Gas Corp',
#  'Chrysler Corporation',
#  'Group Inc',
#  'Norwegian Air Shuttle Bjorn',
#  'Trump Entertainment Resorts Inc',
#  'BofA',
#  'Olympus Corp',
#  'E Corporation',
#  'Gaynor Investment Counsel Inc',
#  'Bombardier Inc',
#  'Twitter',
#  'Integrys Energy Group',
#  'Family Dollar Stores Inc',
#  'Softbank',
#  'Universal Media Corp',
#  'Dalian Wanda Group',
#  'Kitchen Inc',
#  'Rothschild Inc',
#  'BHP Billiton',
#  'Susquehanna Bancshares Inc',
#  'MBT Financial Corp',
#  'Scribd',
#  'Ultrasonic',
#  'Van Tuyl Group',
#  'Verizon',
#  'Excite',
#  'Electronic Arts Inc',
#  'Exchange Group',
#  'Walmart Corp',
#  'Advisor Inc',
#  'Visteon',
#  'Tucows Inc',
#  'Eye Inc',
#  'Resources',
#  'Westport Mortgage',
#  'Shake Shack',
#  'Canadian Mortgages Inc',
#  'Tyson Foods Inc',
#  'Target Corp',
#  'Chase',
#  'Mozilla',
#  'China Investment Corporation',
#  'Guangdong Nuclear Power Holding Corp',
#  'Concur Technologies Inc',
#  'Ex Group',
#  'Benefit Guarantee Corporation',
#  'Unicharm Corp',
#  'Trade Group',
#  'Sumitomo Mitsui Financial Group Inc',
#  'Mogul Corp',
#  'Morgan Ventures Energy Corp',
#  'Magic Leap Inc',
#  'Suning Commerce Group',
#  'Braintree',
#  'Wedbush Morgan Securities Inc',
#  'Club Med and Huabei Group',
#  'Bank Corp',
#  'The Elevation Group',
#  'Pro',
#  'Hammerstone Group',
#  'Dish Network',
#  'O Corporation',
#  'Uber',
#  'Australia Industry Group',
#  'Industrial Products Corporation',
#  'Dermott International Inc',
#  'Hilton & Hyland',
#  'IGT',
#  'Agile Property Holdings',
#  'Bezos Expeditions',
#  'Walmart Stores Inc',
#  'African Broadcasting Corporation',
#  'High Lantern Group',
#  'Safeway Inc',
#  'Because Corporation',
#  'Mattel Inc',
#  'Investor Protection Trust',
#  'R Corporation',
#  'AC Propulsion',
#  'Publicis Mojo Group',
#  'Best Buy Inc',
#  'Elliot Management Corp',
#  'Financial Guaranty Corp',
#  'Northrop Grumman',
#  'Lorillard Tobacco',
#  'Pimco',
#  'Countrywide Financial Corp',
#  'Cambridge Group',
#  'Sands China Ltd',
#  'Westpac Banking Corp',
#  'Renesas Electronics Corp',
#  'Digital Equipment Corporation',
#  'BBC',
#  'Foxconn Technology Group',
#  'Meredith Corp',
#  'Garland',
#  'Newman Corp',
#  'Citadel',
#  'Arizona',
#  'Stop Corp',
#  'Superb Summit International Group',
#  'Retirement Inc',
#  'Kynikos Investments',
#  'Covington',
#  'Berkshire Hathaway Assurance Corp',
#  'American Airlines',
#  'Caracal Energy',
#  'Avis Budget Group Inc',
#  'Barclays Capital Inc',
#  'Repsol',
#  'Alcor Micro Corp',
#  'Encana Corp',
#  'Alcatel',
#  "Pilgrim's",
#  'Harvard Management Company',
#  'Yard Development Corporation',
#  'Energy Corporation',
#  'Takata Corp',
#  'Sun Art Retail Group',
#  'And China Investment Corporation',
#  'Advent International Corporation',
#  'Applied Materials Inc',
#  'Vogel Capital Management',
#  'Frontline',
#  'Yelp Inc',
#  'Peregrine Financial Group',
#  'Matters Exxon Mobil Corp',
#  'Nutronics Labs',
#  'Japan Airlines Co Ltd',
#  'Janus Capital Group',
#  'VTB',
#  'CardsChat.com',
#  'Seabreeze Partners Management',
#  'Quest',
#  'Swanson',
#  'Mina Kimes',
#  'International Lease Finance Corp',
#  'Advanced Technologies Inc',
#  'US Airways',
#  'Allianz',
#  'Oracle Corp',
#  'Fuels Corporation',
#  'ITT Corp',
#  'Cantwell',
#  'SocGen',
#  'Buffalo Wild Wings Inc',
#  'Banking Group',
#  'Centennial Group',
#  'Hearst Corporation',
#  'General Motors',
#  'Exxon Mobil Corp',
#  'Enron Corp',
#  'Chinese Mobile',
#  'Pershing Advisor Solutions',
#  'Kimco',
#  'American Tower Corp',
#  'Franklin Resources Inc',
#  'Mobile',
#  'Samsung General Chemicals Co Ltd',
#  'Pershing Square',
#  'AngelHack',
#  'Detroit Transportation Corporation',
#  'Marijuana Industry Group',
#  'Molina Healthcare Inc',
#  'Energie',
#  'Tudor Investment Corporation',
#  'Oakley Inc',
#  'FAB Universal Corp',
#  'Morningstar',
#  'Iliad',
#  "Kohl's Corp.",
#  'Air Lease Corp',
#  'Direxion',
#  'Bank Resolution Corporation',
#  'EMC',
#  'Ipanema',
#  'MF Global',
#  'Coinbase Inc',
#  'Anaplan',
#  'Wisconsin Steel Corporation',
#  'Australian Broadcasting Corp',
#  'Embraer Commercial Aviation',
#  'Vision Knight Capital',
#  'Citic Offshore Helicopter Co Ltd',
#  'Imperial Tobacco Group',
#  'Kendra Todd Group',
#  'Dior',
#  'Mobile Inc',
#  'Visa',
#  'Union Square Ventures',
#  'RMI',
#  'Cultural Group',
#  'Lucent',
#  'Saudi Basic Industries Corporation',
#  'In Corporation',
#  'Venoco',
#  'Rolex',
#  'Home Loan Mortgage Corporation',
#  'McDonalds',
#  'Shell Oil Co',
#  'Commodity Weather Group',
#  'Oracle Corporation',
#  'Samsung Engineering Co Ltd',
#  'Mitsubishi Corporation',
#  'Ball Corporation',
#  'Texas Pacific Group',
#  'Solaris Group',
#  'The Internet Corporation',
#  'Mart Corp',
#  'Railway Construction Corporation',
#  'Afghan International Bank',
#  'Olam International Ltd',
#  'CNR Corp',
#  'Sotheby',
#  'United Therapeutics Corp',
#  'Templeton Emerging Markets Group',
#  'Cisco Systems',
#  'Options Group',
#  'Franklin Resources',
#  'Suntech Power Holdings',
#  'Nintendo Co Ltd',
#  'Electus',
#  'Xerox Corporation',
#  'Ibarra Strategy Group',
#  'JP Morgan Chase',
#  'Walter Investment Management Corp',
#  'Merrill Lynch',
#  'Wells Fargo',
#  'Billionaire Tesla',
#  'Thomson Reuters Loan Pricing Corp',
#  'Celgene Corporation',
#  'Vistory Social Capital',
#  'Emile Garcin',
#  'American Eagle',
#  'Galvon',
#  'Trian Fund Management',
#  'Coatue Management',
#  'Boeing Commercial Airplanes',
#  'Space Expedition Corp',
#  'Exxon',
#  'Ritholtz Wealth',
#  'Container Store Group Inc',
#  'Verifone Systems Inc',
#  'Long Island Plastic Surgical Group',
#  'The Gartman Letter',
#  'Nomura Holdings Inc',
#  'Lockheed Martin',
#  'General Dynamics Corp',
#  'Resolution Trust Corporation',
#  'Chambers Street Properties',
#  'Weaved',
#  'Swatch',
#  'The Chrysler Group',
#  'Jiayuan Group',
#  'Latam Airlines Group',
#  'United Technologies Corp',
#  'Wanda Cinema Line Co Ltd',
#  'Bloomberg Media',
#  'Stryker Corp',
#  'Star Banc Corporation',
#  'Scottrade Inc',
#  'Irving Oil',
#  'Wealthy Investors Are Inc',
#  'Hillshre Brands',
#  'Wintek Corp',
#  'Fir Tree Partners Inc',
#  'INTRIX',
#  'ACA Financial Guaranty Corp',
#  'Medex Inc',
#  'Colorado Inc',
#  'Titan',
#  'Gilead',
#  'Omega Advisors',
#  'JPMorgan Chase',
#  'AdvisorShares',
#  'Fitch shares',
#  'Cisco',
#  'T-Mobile',
#  'State Street Corp',
#  'Hewlett Packard Co',
#  'Sorinet Group',
#  'Sprint',
#  'Fifth Generation Inc',
#  'The Earned Inc',
#  'Tencent Holdings Ltd',
#  'TIAA-CREF',
#  'Valueant',
#  'Shanghai Film Co Ltd',
#  'Idealab',
#  'Sony',
#  'Pride Corp',
#  'CVS Caremark',
#  'Corporate Inc',
#  'Truepoint Inc',
#  'ANXBTC',
#  'Eurogroup Working Group',
#  'Siemens America',
#  'Hayman Capital',
#  'Media Corporation',
#  'Johns Manville Corp',
#  'SearchMedia Holdings',
#  'Juneyao Group',
#  'Herblife',
#  'Bryant Park Corporation',
#  'State Grid Corp',
#  'Emperor Group',
#  'Naver Corp',
#  'Pinnacle West Capital Corp',
#  'Bitcoin China',
#  'Lear Corp',
#  'Public Interest Research Group',
#  'Washington Mutual Inc',
#  'Gilead Sciences',
#  'Nasty Gal',
#  'JPMorgan Corp',
#  'Dendreon Corporation',
#  'Investors Chasing Inc',
#  'Sainsbury',
#  'Textron Inc',
#  'Aetna Inc',
#  'Biogen Idec Inc',
#  'Fundstrat Global Advisors',
#  'Laboratory Skin Care',
#  'Brunswick Corporation',
#  'Quicken Loans',
#  'Carnival Corporation',
#  'Cintas Corporation',
#  'Daddy Inc',
#  'Amadeus',
#  'Neusoft Corp',
#  'Gas Corporation',
#  'Lazard Ltd',
#  'AiresBuenos',
#  'National Distillers Products Corporation',
#  'International Finance Corporation',
#  'Humana Inc',
#  'Alcatel-Lucent',
#  'Dialectic Capital Management',
#  'BMO Capital Markets',
#  'Citizens Energy Corporation',
#  'Las Vegas Sands Corp',
#  'Principal Financial Group',
#  'K. Hovnanian',
#  'Mandiant',
#  'United States Marine Corp',
#  'D Corporation',
#  'Research Affiliates',
#  'Potash Corporation',
#  'Wet Seal',
#  'Howard Hughes Corporation',
#  'Newman Corporation',
#  'Environmental Working Group',
#  'Post Holdings',
#  'Equipment Rental Corporation',
#  'TJ Maxx',
#  'Ascena',
#  'Pantech Co',
#  'GreenLight Capital',
#  'China Railway Construction Corp',
#  'Basic Industries Corporation',
#  'U.S. Travel Association',
#  'Mars Corp',
#  'Nuclear Energy Corporation',
#  'BlackBerry',
#  'Too Much Power Over Corp',
#  'Barrick Gold Corp',
#  'Agrium Inc',
#  'Huawei Technologies Co Ltd',
#  'Shanghai Chaori Solar Energy Science and Technology Company',
#  'Amgen Inc',
#  'Priceline',
#  'Apple',
#  'Hilton Worldwide Holdings Inc',
#  'Samsung Group',
#  'Springleaf Finance',
#  'Shenzhen Liye Group',
#  'DirecTV',
#  'White Lodging',
#  'DoubleLine Capital',
#  'Hub',
#  'Wisconsin Energy Corp',
#  'Gulfstream Aerospace Corporation',
#  'Marathon Oil Corp',
#  'Dalian Wanda Commercial Properties Co Ltd',
#  'Dumex Baby Food Co Ltd',
#  'Global Markets Inc',
#  'C Securities Corporation',
#  'Sequence Inc',
#  'ExxonMobil',
#  'Goldman Sachs Group Inc',
#  'Securities International Co Ltd',
#  'Employee Retirement Inc',
#  'United Parcel Service Inc.',
#  'Orix Corp',
#  'Hainan Airlines Co Ltd',
#  'Karma',
#  'Jamba Inc',
#  'Motorola',
#  'Investment Group',
#  'International Islamic Liquidity Management Corp',
#  'Instagram',
#  'Standard Bank Group',
#  'Realty Corporation',
#  'CDW Corp',
#  'Turkiye Halk Bank',
#  'Financial Services Group',
#  'Zillow',
#  'Hormel Foods Corp',
#  'Poly Real Estate Group',
#  'Bank Clothiers Inc',
#  'Continental Resources Inc',
#  'Guangzhou Automobile Group Co Ltd',
#  'Playboy Enterprises Inc',
#  'Belarus Potash Co',
#  'Link Genetics Corp',
#  'Railway Corporation',
#  'Emric',
#  'Dragon Websoft Inc',
#  'UBS',
#  'Flow Inc',
#  'Virgin America Founding',
#  'Freescale Semiconductor Inc',
#  'Pride Corporation',
#  'Pfizer',
#  'Rowe Price',
#  'Nigerian National Petroleum Corporation',
#  'Zeneca',
#  'Edelman Financial Services LLC',
#  'Blackstone Group',
#  'Crocs',
#  'Albuquerque Home Sales Inc',
#  'State Civil Supplies Corporation',
#  'Alfa Group',
#  'Broadcasting Corporation',
#  'Cadillac Fairview Corporation',
#  'Tekmira Pharmaceuticals Corp',
#  'Shutterfly Inc',
#  'Yum Brands Inc',
#  'Rhodium Group',
#  'Ridge Energy Inc',
#  'Starbucks Corporation',
#  'Intel Corporation',
#  'Blue Airways Corp',
#  'Mortgage Insurance Corporation',
#  'Gap Inc',
#  'Marine Corp',
#  'Oil Corporation',
#  'Gilt Group',
#  'Lloyds Banking Group',
#  'BNSF',
#  'Mars Inc',
#  'Boston Scientific Corp',
#  'Chugai Pharmaceutical Co Ltd',
#  'McKinsey & Company',
#  'Hedgeye',
#  'Interactive Data Corp',
#  'The Vanguard Group',
#  'Rental Corporation',
#  'Bitcoin',
#  'Allegheny Technologies',
#  'Moncler',
#  'Asset Strategies Group',
#  'Healthy Corp',
#  'Toll Brothers',
#  'Drilling Info Inc',
#  'HSBC',
#  'Athenahealth',
#  'Contact Group',
#  'The Charles Schwab Corporation',
#  'Stocktwits',
#  'Tommy Hilfiger',
#  'Jadwa',
#  'The Advisory Group',
#  'Marwood Group',
#  'The National Inc',
#  'Kemper Corp',
#  'Shares High Yield Corp',
#  'Overseas Shipholding Group',
#  'Taminco Corp',
#  'Amaya Gaming Group',
#  'Offshore Oil Corporation',
#  'Xerox Inc',
#  'Motorola Mobility Holdings Inc',
#  'America Corp',
#  'Red Peak Branding',
#  'Consenza',
#  'Espirito Santo Financial Group',
#  'Saks Inc',
#  'Washington Research Group',
#  'JP Morgan',
#  'Hyundai Mobis Co Ltd',
#  'Paul Singer',
#  'Charter Communications Inc',
#  'Ascena Retail Group',
#  'The leisure shoe',
#  'Sears',
#  'Japan Broadcasting Corp',
#  'Motors Corporation',
#  'Jones Capital Equities Management Inc',
#  'Sprint Corp',
#  'HSH',
#  'Eleven Inc',
#  'GSC Capital Corp',
#  'Rite Aid',
#  'Lauren Corporation',
#  'Hub Inc',
#  'Tongling Nonferrous Metals Group',
#  'Intucell',
#  'Zappos',
#  'Fleur',
#  'Great Wall Motor Co Ltd',
#  'Siemans',
#  'Fort Pitt Capital Group',
#  'Consumer Bank',
#  'Airbus',
#  'Abengoa',
#  'Wanxiang Group',
#  'Quicksilver',
#  'M Corporation',
#  'Corcoran Real Estate Group',
#  'Procter & Gamble',
#  'Costco Wholesale Corp',
#  'Chicago Transit Authority',
#  'Henkel',
#  'Commercial Aircraft Corp',
#  'Siemens',
#  'Sumitomo Corporation',
#  'Gross Inc',
#  'Revel Entertainment Corp',
#  'Sogou Inc',
#  'Vegas Sands Corporation',
#  'VMware',
#  'Central Park Group',
#  'Girl Scouts',
#  'Nest Labs Inc',
#  'Waldorf Hilton Worldwide Holdings Inc',
#  'Flowers Foods Inc',
#  'China Business Aviation Group',
#  'Wharf Holdings Ltd',
#  'CoinJar',
#  'Advent International Corp',
#  'Lung Biotechnology Inc',
#  'Corrections Corporation of America',
#  'C Mortgage Corporation',
#  'Vision Inc',
#  'Pharmaceuticals Corporation',
#  'USG Corp',
#  'United Technology Corp',
#  'The Container Store Group',
#  'Feeding America',
#  'Silicon Motion Technology Corp',
#  'Federal Mogul Corporation',
#  'Audience Inc',
#  'Greenwich Associates',
#  'Diversified Machine Inc',
#  'United Technologies',
#  'Clincle',
#  'Wanda Commercial Properties Group',
#  'Canadian Pacific Railway',
#  'Invesco Ltd',
#  'Thomson Reuters',
#  'Yum Brands',
#  'NRG Energy',
#  'Nest',
#  'Barington Capital Group',
#  "Men's Wearhouse",
#  'D Systems Corp',
#  'YAHOO',
#  'First Century Fox Inc',
#  'Centene Corporation',
#  'Tesla Motors Inc.',
#  'Commidea Ltd',
#  'Stores Inc',
#  'HTC',
#  'Twitch',
#  'Capital Holdings Inc',
#  'The Home Depot',
#  'Ambac Assurance Corp',
#  'Pacific Investment Management Co',
#  'Wells Fargo Corp',
#  'American International Group',
#  'Safra Group',
#  'Tesla Motors Inc',
#  'Advanced Technology Inc',
#  'Habit Restaurants Inc',
#  'The Corporation',
#  'MHP',
#  'Mubadala Investment Corporation',
#  'LeFrak',
#  'Bitcoin Satoshi Nakamoto',
#  'Tumblr',
#  'Hillshire Brands Co',
#  'Federal Reserve Bank',
#  'Navy Yard Development Corporation',
#  'Street Corporation',
#  'Ernst',
#  'Kimren Group',
#  'Set Research Systems Inc',
#  'Toyota',
#  'Dropbox',
#  'Pantheon Macroeconomics',
#  'Reilly Automotive Inc',
#  'Stratasys Inc',
#  'Calpine Corp',
#  'Itochu Corp',
#  'Recon Analytics',
#  'Beijing Shiji Information Technology Co Ltd',
#  'Tracinda Corp',
#  'Tesla Motor Inc',
#  'Honeywell International',
#  'Export Now',
#  'Diversified Realty Corporation',
#  'Former Qwest',
#  'Pacific Investment Management',
#  'Halkbank',
#  ...]

# %% [markdown]
# Through observation, we can see that most of the names end with 'Inc', 'Group', 'Ltd', 'Co','Corp', 'Corporation'. Another trend in the company name is a series of capital letters.

# %%
list(filter(lambda x: len(x) == 2, company_names))
# Out:
# ['HP', 'NQ', 'JD', 'GE', 'GM']

# %% [markdown]
# We choose not to filter out the stop words as it is common to have them in the company names, such as 'the'. So our candidates are still consecutive words with first letter capitalized.

# %%
conseCAP = []
for i in range(len(traintext)):
    pairs = re.findall(r" (?:[A-Z]+[A-Za-z0-9']* ?)+",traintext[i])
    for k in range(len(pairs)):
        conseCAP.append(pairs[k].rstrip().strip())
conseCAP = list(conseCAP)

# %%
insamp = [t for t in conseCAP if t in company_names]
insampid = set(insamp)

# %% [markdown]
# The features I used to find company name include:
# * If **company** is in sentence
# * If keywords are in the list of words. (keywords are 'inc', 'group', 'ltd' etc. as a good indicator of company names)
# * If there are numbers in the sentence
# * Number of words in the sentence
# * Number of words of the candidate
# * Number of letters of the candidate
# * Proportion of capital letters
# * If previous word has capital letter in the beginning
# * If next word has capital letter in the beginning

# %%
def featurecomp(sent, CAPS):
#We want to generate a list of features for a word showing up in a sentence. Before running this function we have to
#make sure CAPS is in sent.
    keywords = {'inc', 'group', 'ltd', 'co', 'corp', 'corporation'}
    #These are the key words to identify a company name, we expect the coef for this variable to be high.
    
    capwords = tokenizer.tokenize(CAPS)
    lcapwords = map(lambda x: x.lower(), capwords)
    word = tokenizer.tokenize(sent)
    lwords = map(lambda x : x.lower(), word)
    features = {"words": CAPS}
    features["insample"] = (CAPS in insamp) + 0
    features["company_in_sent"] = ("company" in lwords) + 0
    features["key_in_sent"] = any(list(map(lambda x: x in keywords, lcapwords))) + 0
    
    features["num_in_sent"] = (re.search(r'[0-9]+', sent) != None) + 0
    features["length_of_sent"] = len(word)
    
    wordlist = "".join(CAPS)
    features["num_of_words"] = len(capwords)
    features["length_of_words"] = len(wordlist)
    features["portion_of_CAP"] = sum(map(lambda x: x.isupper(), wordlist))/len(wordlist)
    
    indexf = word.index(capwords[0])
    indexl = word.index(capwords[-1])
    features["prev_capped"] = ((indexf != 0) & (word[indexf-1][0].isupper())) + 0
    features["next_capped"] = ((indexl != len(word) - 1) & (word[-len(word) + indexl + 1][0].isupper())) + 0
    
    return features

# %% [markdown]
# Again, we make sure the length of positive sample list is about the same as the length of negative one.

# %%
poscount = 0
negcount = 0
featuremat = []
wordbank = words.words()
for i in range(len(trainsent)):
    CAPS = re.findall(r" (?:[A-Z]+[A-Za-z0-9']* ?)+", trainsent[i])
    for j in range(len(CAPS)):
        CAPS[j] = CAPS[j].rstrip()
        CAPS[j] = CAPS[j].strip()
        if (CAPS[j] in insampid):
            poscount = poscount + 1
            featuremat.append(featurecomp(trainsent[i], CAPS[j]))

for i in range(len(trainsent)):
    CAPS = re.findall(r" (?:[A-Z]+[A-Za-z0-9']* ?)+", trainsent[i])
    if (negcount >= len(insamp)):
        break
    else:
        for j in range(len(CAPS)):
            CAPS[j] = CAPS[j].rstrip()
            CAPS[j] = CAPS[j].strip()
            indexCAPS = trainsent[i].index(CAPS[j])
            if (not CAPS[j].lower() in wordbank) & ((indexCAPS == 0) | (trainsent[i][indexCAPS - 1] in {".", " "})) & (not (CAPS[j] in insampid)):
                negcount = negcount + 1
                featuremat.append(featurecomp(trainsent[i], CAPS[j]))

# %%
featuremat = pd.DataFrame(featuremat)

# %%
y_train = featuremat["insample"]
X_train = featuremat.drop(["insample", "words"], axis = 1)
X_train = np.array(X_train)
clf2 = svm.SVC(kernel = "rbf", max_iter = 1000)
clf2.fit(X_train, y_train)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:244: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   % self.max_iter, ConvergenceWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=1000, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
conseCAP = []
for i in range(len(testtext)):
    lists = list(set(re.findall(r" (?:[A-Z]+[A-Za-z0-9']* ?)+",testtext[i])))
    for k in range(len(lists)):
        lists[k] = lists[k].rstrip()
        lists[k] = lists[k].strip()
        if (lists[k] not in wordbank):
            conseCAP.append(lists[k])
conseCAP = list(set(conseCAP))

# %% [markdown]
# The remaining process is about the same as the CEO names classifying process

# %%
testmat = []
for i in range(len(testsent)):
    CAPS = re.findall(r" (?:[A-Z]+[A-Za-z0-9']* ?)+", testsent[i])
    CAPS = list(map(lambda x: x.rstrip().strip(), CAPS))
    CAPS = list(filter(lambda x: x in conseCAP, CAPS))
    for j in range(len(CAPS)):
        testmat.append(featurecomp(testsent[i], CAPS[j]))

# %%
testmat = pd.DataFrame(testmat)
X_test = testmat.drop(["insample", "words"], axis = 1)
y_test = testmat["insample"]
clf2.score(X_test, y_test)
# Out:
# 0.8678417199518117

# %%
confusion_matrix(clf2.predict(X_test), np.array(y_test))
# Out:
# array([[232954,  26057],
#        [  9596,   1168]])

# %%
cols = ["company_in_sent", "key_in_sent", "length_of_sent", "length_of_words", "next_capped", "num_in_sent", "num_of_words",  "portion_of_CAP", "prev_capped"]

# %%
def predict_comp(model, sent, CAPS):
    features = featurecomp(sent, CAPS)
    features = pd.DataFrame(features, index = [0])
    X = features.drop(["insample", "words"], axis = 1)
    X = X[cols]
    y = model.predict(X)
    return y[0]

# %%
allcomp = []
for i in range(len(allsent)):
    CAPS = re.findall(r" (?:[A-Z]+[A-Za-z0-9']* ?)+", allsent[i])
    CAPS = list(map(lambda x: x.rstrip().strip(), CAPS))
    CAPS = list(filter(lambda x: x not in allcomp, CAPS))
    for j in range(len(CAPS)):
        if (CAPS[j].lower() not in wordbank):
            if (predict_comp(clf2, allsent[i], CAPS[j]) == 1):
                allcomp.append(CAPS[j])

# %%
allcomp = list(set(allcomp))
with open("predicted_comp.txt", "w") as f:
    for comps in allcomp:
        f.write(comps + "\n")

# %% [markdown]
# ## Percentage

# %% [markdown]
# When cleaning all positively labeled data, we found a large portion of it is just pure numbers, which has nothing to do with percentage. Thus, we decide to use regex expression to extract the percenrages.
#
# They may come in the following format:
# * XX(.XX)%
# * XX(.XX) percent (age point)(s)
# * English described percent

# %%
pattern = r'(([0-9]+)|(one)|(two)|(three)|(four)|(five)|(six)|(seven)|(eight)|(nine)|(ten))[.[0-9]*]?(%| percentage point| percent)+s?'

# %%
allperc = []
for sent in allsent:
    allperc.extend(re.findall(pattern, sent))

# %%
allperc = list(map(lambda x:"".join(x[1:]) , allperc))
allperc = list(set(allperc))
allperc
# Out:
# ['26 percent',
#  '23%',
#  '44%',
#  'five percent',
#  '34 percent',
#  '38 percent',
#  '167%',
#  '95%',
#  '328%',
#  '700%',
#  '660%',
#  '106%',
#  '182%',
#  '89%',
#  '72%',
#  '32 percentage point',
#  '282%',
#  '91%',
#  '450%',
#  '386 percent',
#  '201 percent',
#  '213 percent',
#  '357%',
#  '108 percent',
#  '1 percent',
#  '05 percent',
#  '524%',
#  '58 percent',
#  '329%',
#  '236 percent',
#  '55%',
#  '660 percent',
#  '14%',
#  '281%',
#  '7 percent',
#  '967%',
#  '1140%',
#  '205 percent',
#  '84 percent',
#  '462%',
#  '289%',
#  '130%',
#  '190 percent',
#  '40 percentage point',
#  '53 percent',
#  '37 percentage point',
#  '114 percent',
#  '145 percent',
#  '09082014%',
#  '37%',
#  '4%',
#  '39 percentage point',
#  '0%',
#  '500%',
#  '226 percent',
#  '61%',
#  '362%',
#  '231%',
#  '385%',
#  '600%',
#  '233%',
#  '260%',
#  '163 percent',
#  '43 percent',
#  '250%',
#  '608%',
#  '799%',
#  '207%',
#  '438%',
#  'eight percent',
#  '340 percent',
#  '396%',
#  'two percentage point',
#  '441%',
#  '131 percent',
#  '84%',
#  '147%',
#  '18%',
#  '433%',
#  '995%',
#  'three percentage point',
#  '249%',
#  '10 percent',
#  '310 percent',
#  '138 percent',
#  '5 percent',
#  '19%',
#  '248 percent',
#  '398%',
#  '172%',
#  '349%',
#  '239%',
#  '151%',
#  '198 percent',
#  '40%',
#  '110 percent',
#  '83%',
#  '11 percentage point',
#  '36 percent',
#  '370%',
#  '220%',
#  '1500%',
#  '162%',
#  '332 percent',
#  '27%',
#  '22 percent',
#  '631%',
#  '020%',
#  '110%',
#  '320%',
#  '480%',
#  '261%',
#  '3%',
#  '361%',
#  '63%',
#  '41%',
#  '417%',
#  '332%',
#  '18 percent',
#  '24%',
#  '283%',
#  '328 percent',
#  '28 percent',
#  '25 percent',
#  '120%',
#  '07%',
#  '343 percent',
#  '89 percent',
#  '16 percent',
#  '203%',
#  '21 percent',
#  '215 percent',
#  '75%',
#  '150 percent',
#  '390 percent',
#  '20 percent',
#  '87 percent',
#  '700 percent',
#  '314%',
#  '376%',
#  '258 percent',
#  '485 percent',
#  '94 percent',
#  '50 percentage point',
#  '12%',
#  '2700%',
#  '294%',
#  '343%',
#  '160%',
#  '000%',
#  '565%',
#  '76%',
#  '123%',
#  '245 percent',
#  '112%',
#  '74%',
#  '364 percent',
#  '291%',
#  '4 percentage point',
#  '723 percent',
#  '360%',
#  '17 percent',
#  '5 percentage point',
#  '1000%',
#  '16 percentage point',
#  '47 percent',
#  '75 percentage point',
#  '219 percent',
#  '136 percent',
#  '847%',
#  '30 percentage point',
#  '42 percent',
#  '148%',
#  '176%',
#  '214%',
#  '526%',
#  '52%',
#  '17%',
#  '330%',
#  '98 percent',
#  '655%',
#  '120 percent',
#  '99%',
#  '122 percent',
#  '185%',
#  '101 percent',
#  '1654%',
#  '25 percentage point',
#  '14 percentage point',
#  '165%',
#  '137%',
#  '35%',
#  '415%',
#  '457%',
#  '472%',
#  '65 percent',
#  '124 percent',
#  '111%',
#  '340%',
#  '60 percentage point',
#  '180%',
#  '892 percent',
#  '7%',
#  '128 percent',
#  'nine percentage point',
#  '66%',
#  '10 percentage point',
#  '296%',
#  '118%',
#  '68%',
#  '212%',
#  '835%',
#  '227%',
#  '29 percent',
#  '171%',
#  '104 percent',
#  '270%',
#  '262%',
#  '9%',
#  '275%',
#  '2 percent',
#  '9 percent',
#  '230%',
#  '146%',
#  '75 percent',
#  '06%',
#  '571 percent',
#  '647 percent',
#  '131%',
#  '257%',
#  '3 percent',
#  '95 percent',
#  '45 percent',
#  '55 percent',
#  '79 percent',
#  '325%',
#  '15 percent',
#  '78 percent',
#  'six percentage point',
#  '251%',
#  '140 percent',
#  '57 percent',
#  '174%',
#  '30 percent',
#  '550%',
#  '114%',
#  '33%',
#  '373%',
#  '232%',
#  '425 percent',
#  '05%',
#  '4 percent',
#  'ten percent',
#  '82%',
#  '080%',
#  '177%',
#  '125 percent',
#  '81%',
#  '80 percent',
#  '9 percentage point',
#  '49%',
#  'four percentage point',
#  '645%',
#  '02%',
#  '1600%',
#  '8 percent',
#  '136%',
#  '69%',
#  '33 percentage point',
#  '579 percent',
#  '144 percent',
#  '34%',
#  '149%',
#  '117%',
#  '600 percent',
#  '150%',
#  '170 percent',
#  '92 percent',
#  '90%',
#  '22%',
#  '570%',
#  'nine percent',
#  '513 percent',
#  '38%',
#  '275 percent',
#  '71 percent',
#  '132%',
#  '49 percent',
#  '36%',
#  '190%',
#  '175 percent',
#  '78%',
#  '5%',
#  '21 percentage point',
#  '370 percent',
#  '100000000000%',
#  '463%',
#  '346 percent',
#  '917%',
#  '68 percent',
#  '6 percentage point',
#  '911%',
#  '300 percent',
#  '10%',
#  '11 percent',
#  '100 percent',
#  '54 percent',
#  '71%',
#  '134%',
#  '274%',
#  '115 percent',
#  '188%',
#  '122%',
#  '254%',
#  '153%',
#  '91 percent',
#  '358%',
#  '99 percent',
#  '12 percentage point',
#  '145%',
#  '32 percent',
#  '270 percent',
#  '305%',
#  '210%',
#  '53%',
#  '3 percentage point',
#  '138%',
#  '457 percent',
#  '1000 percent',
#  '247%',
#  '875 percent',
#  '182 percent',
#  '17 percentage point',
#  '146 percent',
#  '76 percent',
#  '81 percent',
#  '1200%',
#  '423%',
#  '98%',
#  '46 percent',
#  '141%',
#  '217%',
#  '117 percent',
#  '181%',
#  '73 percent',
#  '238%',
#  '759%',
#  '285%',
#  '41 percent',
#  '200%',
#  '87%',
#  '4000 percent',
#  '688%',
#  '32%',
#  '109%',
#  '189%',
#  '129%',
#  '88%',
#  '140%',
#  '96%',
#  '83 percent',
#  '104%',
#  '15 percentage point',
#  'ten percentage point',
#  '470%',
#  '103 percent',
#  '127%',
#  '31%',
#  '177 percent',
#  '450 percent',
#  '0 percentage point',
#  '168%',
#  '460%',
#  '118 percent',
#  '96 percent',
#  '62 percent',
#  '204 percent',
#  '105 percent',
#  '64%',
#  'six percent',
#  '184 percent',
#  '135 percent',
#  '048%',
#  '161%',
#  '180 percent',
#  '240 percent',
#  '20%',
#  '56 percent',
#  '0 percent',
#  '208%',
#  '778%',
#  '163%',
#  '66 percent',
#  '50%',
#  '414%',
#  '141 percent',
#  '85%',
#  '453%',
#  '08%',
#  '11%',
#  '880%',
#  '248%',
#  '500 percent',
#  '61 percent',
#  '547%',
#  '440%',
#  '225%',
#  '28%',
#  '641 percent',
#  '377%',
#  '443%',
#  '19 percentage point',
#  '400 percent',
#  '62%',
#  '30%',
#  '67%',
#  '250 percent',
#  '01 percent',
#  '74 percent',
#  '65%',
#  '107%',
#  '25%',
#  '3382%',
#  '000 percent',
#  '800%',
#  '220 percent',
#  'seven percent',
#  '92%',
#  '166%',
#  '149 percent',
#  '86%',
#  '79%',
#  '23 percentage point',
#  '48 percent',
#  '42%',
#  '653 percent',
#  '204%',
#  '43 percentage point',
#  '115%',
#  '129 percent',
#  '47%',
#  '650%',
#  '619 percent',
#  '326 percent',
#  '224%',
#  '01%',
#  '24 percent',
#  '29%',
#  '400%',
#  '27 percent',
#  '18 percentage point',
#  '46%',
#  '2 percentage point',
#  '39 percent',
#  '45%',
#  '242%',
#  '72 percent',
#  '137 percent',
#  '3000%',
#  '12 percent',
#  '53 percentage point',
#  '1%',
#  '170%',
#  '195%',
#  '67 percent',
#  '339%',
#  '900%',
#  '319 percent',
#  '189 percent',
#  '82 percent',
#  '124%',
#  'five percentage point',
#  '329 percent',
#  '13 percent',
#  '126%',
#  '188 percent',
#  '63 percent',
#  '252%',
#  '69 percent',
#  '16%',
#  '132 percent',
#  '26%',
#  '510%',
#  '105%',
#  '271%',
#  '33 percent',
#  '13%',
#  '192%',
#  '23 percent',
#  '20 percentage point',
#  '200 percent',
#  '5120%',
#  '850%',
#  '800 percent',
#  'one%',
#  '54%',
#  '347%',
#  '77%',
#  '14 percent',
#  '143 percent',
#  '133 percent',
#  '93 percent',
#  '86 percent',
#  '477 percent',
#  '29 percentage point',
#  '853%',
#  '48%',
#  '116%',
#  '36 percentage point',
#  '206%',
#  '7 percentage point',
#  '22 percentage point',
#  '6%',
#  '70%',
#  '102%',
#  '706%',
#  '144%',
#  '334%',
#  '93%',
#  '13 percentage point',
#  '52 percentage point',
#  '491%',
#  '58%',
#  '387%',
#  '159%',
#  '50 percent',
#  '73%',
#  '469%',
#  '40 percent',
#  '35 percent',
#  '245%',
#  '39%',
#  '56%',
#  '52 percent',
#  '142 percent',
#  '44 percent',
#  '88 percent',
#  '1200 percent',
#  '37 percent',
#  '130 percent',
#  '80%',
#  '278%',
#  '101%',
#  '43%',
#  '142%',
#  '165 percent',
#  '286%',
#  '03%',
#  '60 percent',
#  '41 percentage point',
#  '900 percent',
#  '59%',
#  '350%',
#  '440 percent',
#  '26 percentage point',
#  '579%',
#  '537 percent',
#  '164%',
#  '59 percent',
#  '8 percentage point',
#  '57%',
#  '97 percent',
#  '597%',
#  '1 percentage point',
#  'one percentage point',
#  '48 percentage point',
#  '465%',
#  '2013 percent',
#  '123 percent',
#  '15%',
#  '626%',
#  'eight percentage point',
#  '119%',
#  '436%',
#  '197%',
#  '64 percent',
#  '21%',
#  '28 percentage point',
#  '77 percent',
#  '94%',
#  '60%',
#  '260 percent',
#  '90 percent',
#  '868 percent',
#  'two percent',
#  '1900%',
#  '155 percent',
#  '85 percent',
#  'four percent',
#  '175%',
#  '240%',
#  '31 percent',
#  '19 percent',
#  '730%',
#  '504%',
#  '908%',
#  '525%',
#  'one percent',
#  '128%',
#  '2%',
#  '147 percent',
#  'three percent',
#  'seven percentage point',
#  '51%',
#  '97%',
#  '312%',
#  '135%',
#  '230 percent',
#  '121%',
#  '434%',
#  '6 percent',
#  '173%',
#  '100%',
#  '442%',
#  '8%',
#  '70 percent',
#  '156%',
#  '103%',
#  '284%',
#  '518%',
#  '199%',
#  '300%',
#  '303%',
#  '213%',
#  '202%',
#  '51 percent',
#  '125%']

# %%
len(allperc)
# Out:
# 627

# %%
with open("predicted_perc.txt", "w") as f:
    for percs in allperc:
        f.write(percs + "\n")
